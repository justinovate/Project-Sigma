# %% [markdown]
# # **Python Key Points**
# 1. **Interpreted Language**: Python is an interpreted language, which means that code is executed line by line by the Python interpreter. This allows for easier debugging and faster development cycles.
# 2. **High-Level Language**: Python is designed to be human-readable and has a simple and easy-to-learn syntax. This makes it suitable for beginners and experienced programmers alike.
# 3. **Dynamically Typed**: Python is dynamically typed, meaning that you don't need to declare variable types explicitly. The type of a variable is inferred at runtime based on the value assigned to it.
# 4. **Indentation**: Python uses indentation to define code blocks instead of curly braces or keywords like begin and end. This enforces clean and readable code but can also lead to syntax errors if not used correctly.
# 5. **Versatile Usage**: Python is used for a wide range of applications, including web development, data science, machine learning, artificial intelligence, scientific computing, automation, scripting, and more. Its versatility and ease of use make it a popular choice across industries.

# %% [markdown]
# ### Install `ipykernel`
# 1. Run the cell then it will pop up a message saying.
# 2. Running cells with `Python Version` requires ipykernel.
# 3. Click install

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## **Commenting**
# Commenting is the process of adding annotations or remarks within your code to provide explanations, context, or documentation. Comments are not executed by the interpreter/compiler and are purely for the benefit of developers reading the code.
#
# #### **Types of Comments:**

# %% [markdown]
# - **Single-Line Comments:** These comments start with a specific character (e.g., # in Python) and continue until the end of the line. They are suitable for brief annotations or remarks on individual lines of code.

# %%
# This is a single-line comment
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# - **Multi-Line Comments:** While many programming languages support multi-line comments, Python does not have an explicit syntax for them. However, multi-line strings (docstrings) enclosed in triple quotes (""") are often used for this purpose. They are primarily intended for documenting modules, classes, functions, and methods.

# %%
'''
    This is a
    multi-line
    comment.
'''
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# - **Inline Comments:** Inline comments appear on the same line as code and provide additional context or explanation for that specific line of code. However, excessive use of inline comments can clutter the code and reduce readability, so they should be used sparingly and only when necessary.

# %%
print("Hello, World!") # This is an inline comment
# Out:
# Hello, World!

# %% [markdown]
# ## **Variables**
#
# #### **Creating Variables**
#
# Creating a variable in Python is simple. You assign a value to a variable name and start using it. Python figures out the variable type automatically.
#
# #### **Variable Naming Rules**
# - Variable names can contain letters (both uppercase and lowercase), digits, and underscores.
# - They must begin with a letter or an underscore (_), but not with a digit.
# - Case sensitive (myVar and myvar are different variables)
# - Python keywords cannot be used as variable names.

# %%
number = 10
Number = 5
second_number = 15 # snake_case naming convention
print(number)
print(Number)
print(number, Number)
# Out:
# 10
# 5
# 10 5

# %%
# Python keywords cannot be used as variable names.
#  print = "This will print a message." - This will change the functionality of the print() function.

# %%
# Variable names are case sensitive, this will work.
Print = "This is a message."
print(Print)
# Out:
# This is a message.

# %% [markdown]
# ## **Numeric Data Types**
#
# - **int** - Integer values, such as `5`, `-3`, `1000`, etc.

# %%
positive_integer = 30
negative_integer = -30
zero = 0
print("Positive integer", positive_integer)
print("Negative integer", negative_integer)
print("Zero:", zero)
# type(): indentify the data type of a certain variable
print("Data Type of Positive Integer:", type(positive_integer))
print("Data Type of Negative Integer:", type(negative_integer))
print("Data Type of Zero:", type(zero))
# Out:
# Positive integer 30
# Negative integer -30
# Zero: 0
# Data Type of Positive Integer: <class 'int'>
# Data Type of Negative Integer: <class 'int'>
# Data Type of Zero: <class 'int'>

# %% [markdown]
# - **float**: Floating-point values, representing decimal numbers, such as `3.14`, `-0.001`, `2.0`, etc.

# %%
positive_float = 3.14
negative_float = -3.14

print("Positive Float:", positive_float)
print("Negative Float:", negative_float)
print("Data Type of Positive Float:", type(positive_float))
print("Data Type of Negative Float:", type(negative_float))
# Out:
# Positive Float: 3.14
# Negative Float: -3.14
# Data Type of Positive Float: <class 'float'>
# Data Type of Negative Float: <class 'float'>

# %% [markdown]
# ## **Operators and Expressions**
#
# ### **Arithmetic Operators**

# %%
num1 = 10
num2 = 5

print("Addition (+):", num1 + num2)
print("Subtraction (-):", num1 - num2)
print("Multiplication (*):", num1 * num2)
print("Division (/):", num1 / num2)

print("Remainder (%):", num1 % 2) # Even: 0
print("Remainder (%):", 11 % 2) # Odd: 1

# Exponentiation (**)
print("Exponent(**):", num1 ** num2)
# Out:
# Addition (+): 15
# Subtraction (-): 5
# Multiplication (*): 50
# Division (/): 2.0
# Remainder (%): 0
# Remainder (%): 1
# Exponent(**): 100000

# %%
# Order of Operations
# PEMDAS / BODMAS
print(10 + 8 / 4 * (5 - 2) ** 2)
# Out:
# 28.0

# %% [markdown]
# ### **Assignment Operators**

# %%
# 1. Single Equal Sign (=)
num3 = 10
num4 = 5

# 2. Addition Assignment (+=)
# num3 = num3 + num4
num3 += num4
print("The new value of num3: ", num3)
# Computation: 10 + 5 = 15

# 3. Subtraction Assignment (-=)
num3 -= num4
print("The new value of num3:", num3)
# Computation: 15 - 5 = 10

# 4. Multiplication Assignment (*=)
num3 *= num4
print("The new value of num3:", num3)
# Computation: 10 * 5 = 50

# 5. Division Assignment (/=)
num3 /= num4
print("The new value of num3:", num3)
# Computation: 50 / 5 = 10.0
# Out:
# The new value of num3:  15
# The new value of num3: 10
# The new value of num3: 50
# The new value of num3: 10.0

# %% [markdown]
# ## **Boolean Data Type**
# - **bool**: Boolean values representing True or False.

# %%
is_student = False

print("Is the user a student?", is_student)
print("Data type of is_student:", type(is_student))
# Out:
# Is the user a student? False
# Data type of is_student: <class 'bool'>

# %% [markdown]
# ### **Comparison Operators**

# %%
num5 = 10
num6 = 5

print("Equal to (==):", num5 == num6)
print("Not Equal to (!=):", num5 != num6)
print("Greater than (>):", num5 > num6)
print("Less than (<):", num5 < num6)
print("Greater than or Equal to (>=):", num5 >= num6)
print("Less than or Equal to (<=):", num5 <= num6)
# Out:
# Equal to (==): False
# Not Equal to (!=): True
# Greater than (>): True
# Less than (<): False
# Greater than or Equal to (>=): True
# Less than or Equal to (<=): False

# %% [markdown]
# ### **Logical Operators**

# %%
# and, or, not
sunny = False
warm = True

# And: true only if both conditions are true
print("Is it sunny AND warm?", sunny and warm)

# Or: true if at least one condition is true
print("Is it sunny OR warm?", sunny or warm)

# Not: inverts the truth value of a condition
print("Is it NOT sunny?", not sunny)
# Out:
# Is it sunny AND warm? False
# Is it sunny OR warm? True
# Is it NOT sunny? True

# %% [markdown]
# ## **Strings and String Methods**
#
# Strings are sequences of characters and are among the most used data types in Python, especially in data analytics for processing text data.
#
# #### **Introduction to Strings**
#
# Strings in Python are created by enclosing characters in quotes. Python treats single quotes (') and double quotes (") as the same, allowing you to incorporate one type of quote within another including an apostrophe within a string.
#
# #### **Creating and Accessing Strings**

# %%
first_name = "John"
last_name = "Doe"

print("First Name:", first_name)
print("Last Name:", last_name)
print("Data Type of First Name:", type(first_name))
print("Length of First Name:", len(first_name))
# Out:
# First Name: John
# Last Name: Doe
# Data Type of First Name: <class 'str'>
# Length of First Name: 4

# %%
# Indexing
message = "Hello Python! I love Python."
print("First character:", message[0]) # H
print("Last character:", message[len(message) - 1]) # .
print("Last character:", message[-1]) # .
# Out:
# First character: H
# Last character: .
# Last character: .

# %%
# Slicing Parameters
# [starting_index: ending_index (exclusive): step]
print("Slice the string from index 0 to 4:", message[0:5]) # Hello

# step parameter determines how many characters to skip between each selected character.
# positve step: left to right
# negative step: right to left
print("Step/Skip 2:", message[::2])
print("Reverse the string:", message[::-1])
# Out:
# Slice the string from index 0 to 4: Hello
# Step/Skip 2: HloPto!Ilv yhn
# Reverse the string: .nohtyP evol I !nohtyP olleH

# %% [markdown]
# ### **String Methods**

# %%
course = "data analytics"

print("Capitalize:", course.capitalize())
print("Title:", course.title())
print("Uppercase:", course.upper())
print("Lowercase:", course.lower())
# Out:
# Capitalize: Data analytics
# Title: Data Analytics
# Uppercase: DATA ANALYTICS
# Lowercase: data analytics

# %%
# Searching for a certain character
print("Find analytics in course:", course.find("analytics"))
print("Find science in course:", course.find("science"))
print("Find a:", course.find("a"))

print("Is analytics in course:", "analytics" in course)
print("Is science in course:", "science" in course)
print("Is a in course:", "a" in course)

print("Replace:", course.replace("analytics", "science"))
# Out:
# Find analytics in course: 5
# Find science in course: -1
# Find a: 1
# Is analytics in course: True
# Is science in course: False
# Is a in course: True
# Replace: data science

# %% [markdown]
# ### **Concatenation, Formatted String, and .format() Method**

# %% [markdown]
# - **Concatenation**

# %%
print(first_name, last_name)
print("Concatenation:", first_name + " " + last_name)
# Out:
# John Doe
# Concatenation: John Doe

# %% [markdown]
# - **Formatted Strings Literals (f-strings)**

# %%
print(f"Formatted Strings: {first_name} {last_name}")
# Out:
# Formatted Strings: John Doe

# %% [markdown]
# - **.format() method**

# %%
introduction = """
Hello my name is {first_name} {last_name}!
I am {age}. I want to learn {course}.
"""

print(introduction.format(first_name = "David",
                    last_name = "Smith",
                    age=30,
                    course="Data Analytics"))
# Out:
# Hello my name is David Smith!
# I am 30. I want to learn Data Analytics.

# %% [markdown]
# ## **Lists and List Methods**
#
# #### **Introduction to Lists**
#
# Lists are mutable sequences, meaning you can modify them after creation. They can contain items of any type, making them incredibly versatile for data collection and manipulation tasks.
#
# - Mutability: Lists are mutable, meaning their elements can be changed after creation.
# - Syntax: Lists are enclosed in square brackets ([]), and elements are separated by commas.
# - Indexing and Ordering: Lists are ordered collections, preserving the order of elements. Elements can be accessed using indices.
# - Usage: Lists are suitable for mutable sequences of items, like arrays, stacks, or queues.
#
# #### **Creating and Modifying Lists**

# %%
# Create a list
numbers = [1, 2, 3, 4, 5]
fruits = ["Apple", "Banana", "Cherry"]
mixed_list = [30, 3.14, "Mango", True]

print("Numbers:", numbers)
print("Fruits:", fruits)
print("Mixed List:", mixed_list)
print("Data Type of the List", type(mixed_list))
print("Length of Mixed List", len(mixed_list))
# Out:
# Numbers: [1, 2, 3, 4, 5]
# Fruits: ['Apple', 'Banana', 'Cherry']
# Mixed List: [30, 3.14, 'Mango', True]
# Data Type of the List <class 'list'>
# Length of Mixed List 4

# %%
# List Indexing
print("First Element:", fruits[0])
print("Last Element:", fruits[-1])
print("Last Element:", fruits[len(fruits) - 1])
# Out:
# First Element: Apple
# Last Element: Cherry
# Last Element: Cherry

# %%
# List Slicing
# [starting_index:ending_index(excluded):step]
print("Fruits:", fruits[1:])
print("Numbers", numbers[1:4])
# Out:
# Fruits: ['Banana', 'Cherry']
# Numbers [2, 3, 4]

# %%
# List Slicing
# [starting_index:ending_index(excluded):step]
print("Fruits:", fruits[1:])
print("Numbers", numbers[1:4])
print("Numbers", numbers[::2])
print("Reverse the list:", numbers[::-1])
# Out:
# Fruits: ['Banana', 'Cherry']
# Numbers [2, 3, 4]
# Numbers [1, 3, 5]
# Reverse the list: [5, 4, 3, 2, 1]

# %% [markdown]
# #### **List Methods**

# %%
programming_languages = ["Python", "JavaScript", "PHP", "C#", "C++"]

# == ADD ==
# append(element) - Add an element at the end of the list
programming_languages.append("Ruby")
print("Prgramming Languages:", programming_languages)

# insert(index, element) - Add an element at a specified index
programming_languages.insert(1, "Java")
print("Prgramming Languages:", programming_languages)

# copy()
copy_of_programming_languages = programming_languages.copy()
print("Copy of Programming Languages:", copy_of_programming_languages)
# Out:
# Prgramming Languages: ['Python', 'JavaScript', 'PHP', 'C#', 'C++', 'Ruby']
# Prgramming Languages: ['Python', 'Java', 'JavaScript', 'PHP', 'C#', 'C++', 'Ruby']
# Copy of Programming Languages: ['Python', 'Java', 'JavaScript', 'PHP', 'C#', 'C++', 'Ruby']

# %%
# == DELETE ==
# Delete an element at the end/specified index of the list
popped_element = programming_languages.pop()
print(programming_languages)
print(popped_element)
programming_languages.pop(2)
print(programming_languages)

# .remove(element) method - (element is required)
programming_languages.remove("PHP")
print(programming_languages)

del programming_languages[0]
print(programming_languages)

print("Is Python in list?", "Python" in programming_languages)

# clear()
programming_languages.clear()
print(programming_languages)
# Out:
# ['Python', 'Java', 'JavaScript', 'PHP', 'C#', 'C++']
# Ruby
# ['Python', 'Java', 'PHP', 'C#', 'C++']
# ['Python', 'Java', 'C#', 'C++']
# ['Java', 'C#', 'C++']
# Is Python in list? False
# []

# %% [markdown]
# #### **List Extending**

# %%
list_of_letters = ["a", "b", "c", "d"]
list_of_numbers = [1, 2, 3, 4]

print(list_of_letters, list_of_numbers)

# Extend the list with another list
list_of_letters.extend(list_of_numbers)
print(list_of_letters)
# Out:
# ['a', 'b', 'c', 'd'] [1, 2, 3, 4]
# ['a', 'b', 'c', 'd', 1, 2, 3, 4]

# %% [markdown]
# #### **Sorting List**

# %%
list_of_numbers = [9, 1, 8, 2, 7, 3, 6, 4, 5]
list_of_numbers.sort()
print(list_of_numbers)

# Sorting in reverse order
list_of_numbers.sort(reverse=True)
print(list_of_numbers)

list_of_names = ["Lancelot", "Galahad", "Arthur", "Percival"]
list_of_names.sort()
print(list_of_names)

list_of_names.sort(reverse=True)
print(list_of_names)

# .reverse(): reversing but not sorting
list_of_numbers.reverse()
print(list_of_numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
# ['Arthur', 'Galahad', 'Lancelot', 'Percival']
# ['Percival', 'Lancelot', 'Galahad', 'Arthur']
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## **Tuples**
#
# **Introduction to Tuples**
#
# Tuples are ordered collections of items, just like lists. However, their immutability makes them useful for fixed data sequences and can serve as keys in dictionaries due to their hashable nature.
#
# - Mutability: Tuples are immutable, meaning their elements cannot be changed after creation.
# - Syntax: Tuples are enclosed in parentheses (()), and elements are separated by commas.
# - Indexing and Ordering: Tuples are ordered collections, preserving the order of elements. Elements can be accessed using indices.
# - Usage: Tuples are suitable for immutable sequences, often used for fixed collections of data.
#
# #### **Creating a tuple**

# %%
numbers_tuple = (1, 2, 3, 4, 5)
print("Numbers Tuple:", numbers_tuple)
print("Data Type of numbers_tuple:", type(numbers_tuple))
# Out:
# Numbers Tuple: (1, 2, 3, 4, 5)
# Data Type of numbers_tuple: <class 'tuple'>

# %% [markdown]
# #### **Accessing Elements**

# %%
print("First Number:", numbers_tuple[0])
# Out:
# First Number: 1

# %% [markdown]
# #### **Tuple Immutability**

# %%
# numbers_tuple[0] = 11
# print(tuple_data) This will not work

# %% [markdown]
# ## **Dictionaries and Dictionary Methods**
#
# #### **Introduction to Dictionaries**
#
# Dictionaries in Python are unordered collections of items. While lists are indexed by a range of numbers, dictionaries are indexed by keys, which can be any immutable type; strings and numbers can always be keys.
# - Mutability: Dictionaries are mutable, meaning they can be modified by adding, updating, or removing key-value pairs.
# - Syntax: Dictionaries are enclosed in curly braces ({}), with key-value pairs separated by colons (:) and items separated by commas.
# - Indexing and Ordering: Dictionaries are unordered collections, and elements are accessed using keys rather than indices.
# - Usage: Dictionaries are suitable for key-value mappings, efficient lookup, and representing structured data
#
# #### **Creating a dictionary and accessing values**

# %%
dict_person = {
    "first_name": "Will",
    "last_name": "Smith",
    "age": 30,
    "address": "123 Example Street",
    "is_married": True,
    "skills": ["singing", "dancing", "acting"]
}

print("Will Smith:", dict_person)
print("Data Type of dict_person:", type(dict_person))
# Out:
# Will Smith: {'first_name': 'Will', 'last_name': 'Smith', 'age': 30, 'address': '123 Example Street', 'is_married': True, 'skills': ['singing', 'dancing', 'acting']}
# Data Type of dict_person: <class 'dict'>

# %%
# Dictionary Indexing
print("Skills:", dict_person["skills"])
print("Skills 1:", dict_person["skills"][0])
print("Skills 2:", dict_person["skills"][1])
# Out:
# Skills: ['singing', 'dancing', 'acting']
# Skills 1: singing
# Skills 2: dancing

# %% [markdown]
# #### **Dictionary Methods**

# %%
# .get(key)
print("Skills:", dict_person.get("skills"))
print("Gender:", dict_person.get("gender"))
# Out:
# Skills: ['singing', 'dancing', 'acting']
# Gender: None

# %%
# == ADD ==
dict_person["gender"] = "Male"
print(dict_person)
# Out:
# {'first_name': 'Will', 'last_name': 'Smith', 'age': 30, 'address': '123 Example Street', 'is_married': True, 'skills': ['singing', 'dancing', 'acting'], 'gender': 'Male'}

# %%
# Getting all the keys
print("Keys:", dict_person.keys())

# Getting all the values
print("Values:", dict_person.values())

# Getting the key and the value pair
print("Items:", dict_person.items())
# Out:
# Keys: dict_keys(['first_name', 'last_name', 'age', 'address', 'is_married', 'skills', 'gender'])
# Values: dict_values(['Will', 'Smith', 30, '123 Example Street', True, ['singing', 'dancing', 'acting'], 'Male'])
# Items: dict_items([('first_name', 'Will'), ('last_name', 'Smith'), ('age', 30), ('address', '123 Example Street'), ('is_married', True), ('skills', ['singing', 'dancing', 'acting']), ('gender', 'Male')])

# %%
# == UPDATE ==
dict_person["last_name"] = "Doe"
print(dict_person)

# update()
dict_person.update({"age": 19, "pet": "Brownie"})
print(dict_person)

# setdefault(key, default_value)
# return the original if you have but give a default if you don't have.
dict_person.setdefault("occupation", "Unemployed")
print(dict_person)
# Out:
# {'first_name': 'Will', 'last_name': 'Doe', 'age': 30, 'address': '123 Example Street', 'is_married': True, 'skills': ['singing', 'dancing', 'acting'], 'gender': 'Male'}
# {'first_name': 'Will', 'last_name': 'Doe', 'age': 19, 'address': '123 Example Street', 'is_married': True, 'skills': ['singing', 'dancing', 'acting'], 'gender': 'Male', 'pet': 'Brownie'}
# {'first_name': 'Will', 'last_name': 'Doe', 'age': 19, 'address': '123 Example Street', 'is_married': True, 'skills': ['singing', 'dancing', 'acting'], 'gender': 'Male', 'pet': 'Brownie', 'occupation': 'Unemployed'}

# %%
# Delete a key:value pair
del dict_person["gender"]
print(dict_person)
# Out:
# {'first_name': 'Will', 'last_name': 'Doe', 'age': 19, 'address': '123 Example Street', 'is_married': True, 'skills': ['singing', 'dancing', 'acting'], 'pet': 'Brownie', 'occupation': 'Unemployed'}

# %%
# .pop(key)
dict_person.pop("is_married")
print(dict_person)
# Out:
# {'first_name': 'Will', 'last_name': 'Doe', 'age': 19, 'address': '123 Example Street', 'skills': ['singing', 'dancing', 'acting'], 'pet': 'Brownie', 'occupation': 'Unemployed'}

# %%
# dict_person.clear()
# print(dict_person)

# %%
# Iterate over each key/value using a 'for loop'.
print("== Working with Keys ==")
for key in dict_person.keys():
    print(key)
# Out:
# == Working with Keys ==
# first_name
# last_name
# age
# address
# skills
# pet
# occupation

# %%
print("== Working with Values ==")
for value in dict_person.values():
    print(value)
# Out:
# == Working with Values ==
# Will
# Doe
# 19
# 123 Example Street
# ['singing', 'dancing', 'acting']
# Brownie
# Unemployed

# %% [markdown]
# ## **Control Flow and Statements**

# %% [markdown]
# #### **Conditional Statements:**
# Allow us to execute different blocks of code based on a condition.
#
# - **if, elif, else statements**

# %%
temperature = 35

if temperature < 0:
    print("It is freezing.")
elif temperature >= 0 and temperature < 20:
    # 0 - 19
    print("It's cool.")
elif temperature > 20 and temperature < 30:
    # 20 - 29
    print("It's warm.")
else:
    print("It's too hot.")
# Out:
# It's warm.

# %%
age = 25
has_license = True
is_student = True

if age >= 18 and has_license:
    print("You are eligible to drive.")
elif age >= 19 and not is_student:
    print("You are eligible to work.")
elif age < 18 or not has_license:
    print("You are not eligible to drive or work.")
else:
    print("You are a student.")
# Out:
# You are eligible to drive.

# %%
day = "Tuesday"

match day:
    case "Monday":
        print("It's the first day of the week.")
    case "Friday":
        print("It's the end of the weekdays.")
    case _:
        print("It's a normal day.")
# Out:
# It's a normal day.

# %% [markdown]
# #### **Looping Statements:**
# Repeatedly execute a block of code until a specific condition is met.
#
# - **for Loop**

# %%
# Looping through a list
numbers = [1, 2, 3, 4, 5]

for number in numbers:
    print("Number:", number)
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5

# %%
# Looping through a dictionary items(key and value pair.)
for key, value in dict_person.items():
    print(f"key: {key}, value: {value}")
# Out:
# key: first_name, value: Will
# key: last_name, value: Doe
# key: age, value: 19
# key: address, value: 123 Example Street
# key: skills, value: ['singing', 'dancing', 'acting']
# key: pet, value: Brownie
# key: occupation, value: Unemployed

# %%
# range(starting_index, ending_index(exluded), step)
for i in range(10, 0, -1):
    print(f"Number {i}")
# Out:
# Number 10
# Number 9
# Number 8
# Number 7
# Number 6
# Number 5
# Number 4
# Number 3
# Number 2
# Number 1

# %% [markdown]
# - **while Loop**

# %%
counter = 1

while counter <= 3:
    print("Counter:", counter)
    counter += 1
else:
    print("While loop is done!")
# Out:
# Counter: 1
# Counter: 2
# Counter: 3
# While loop is done!

# %%
counter = 0

while (counter <= len(list_of_names)):
    if list_of_names[counter] == "Percival":
        print("We found Percival!")
        break
    counter += 1
# Out:
# We found Percival!

# %% [markdown]
# ## **Functions**
#
# - Groups code together into a block.
# - Allows us to call and reuse code efficently.
# - It could take in information (parameters) and return information (return statement) to the caller.

# %%
def greet():
    print("Hello and welcome to the world of functions.")
    print("Let's gooo!!!")

# calling a function
greet()
greet()
# Out:
# Hello and welcome to the world of functions.
# Let's gooo!!!
# Hello and welcome to the world of functions.
# Let's gooo!!!
# Hello and welcome to the world of functions.
# Let's gooo!!!
