# %% [markdown]
# # **SQL Exercise**

# %% [markdown]
# ## **Activity 1**
#
# Practice performing CRUD operations (Create, Read, Update, Delete) on a database table.
#
# ### **Perform the following tasks:**

# %%
import sqlite3

# %% [markdown]
# 1. Connect to the database `abc_corp.db` and create the cursor.

# %%
conn = sqlite3.connect("abc_corp.db")
cursor = conn.cursor()

# %% [markdown]
# 2. `Create` a new table named books, with the following columns:
#   * book_id (primary Key)
#   * title (Title of the book)
#   * author (Author of the book)
#   * genre (Genre of the book)
#   * publication_year (Year of publication)
#   * price (Price of the Book)

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS books (
    book_id INTEGER PRIMARY KEY AUTOINCREMENT,
    title VARCHAR(100) NOT NULL,
    author VARCHAR(100) NOT NULL,
    genre VARCHAR(50) NOT NULL,
    publication_year INT NOT NULL,
    price DECIMAL(8, 2) NOT NULL
);
""")
conn.commit()

# %% [markdown]
# 3. `Insert` at least 5 new books into the books table.

# %%
books = [
    ("The Silent Forest", "Maria Lopez", "Mystery", "2018", 12.99),
    ("Beyond the Stars", "James Carter", "Science Fiction", "2021", 15.50),
    ("Love in Manila", "Ana Reyes", "Romance", "2019", 9.75),
    ("The Last Empire", "David Chen", "Fantasy", "2017", 18.20),
    ("Mind Over Matter", "Sophia Patel", "Self-Help", "2022", 14.00)
]

cursor.executemany("""
INSERT INTO books (title, author, genre, publication_year, price)
VALUES (?, ?, ?, ?, ?)
""", books)

conn.commit()

# %% [markdown]
# 4. `Retrieve` all books from the books table.

# %%
cursor.execute("SELECT * FROM books;")
cursor.fetchall()
# Out:
# [(1, 'The Silent Forest', 'Maria Lopez', 'Mystery', 2018, 12.99),
#  (2, 'Beyond the Stars', 'James Carter', 'Science Fiction', 2021, 15.5),
#  (3, 'Love in Manila', 'Ana Reyes', 'Romance', 2019, 9.75),
#  (4, 'The Last Empire', 'David Chen', 'Fantasy', 2017, 18.2),
#  (6, 'The Silent Forest', 'Maria Lopez', 'Mystery', 2018, 12.99),
#  (7, 'Beyond the Stars', 'James Carter', 'Science Fiction', 2021, 15.5),
#  (8, 'Love in Manila', 'Ana Reyes', 'Romance', 2019, 9.75),
#  (9, 'The Last Empire', 'David Chen', 'Fantasy', 2017, 18.2),
#  (10, 'Mind Over Matter', 'Sophia Patel', 'Self-Help', 2022, 14)]

# %% [markdown]
# 5. `Update` the price of a specific book.

# %%
cursor.execute("""
UPDATE books
SET price = 13.99
WHERE book_id = 5;
""")
conn.commit()

# %% [markdown]
# 6. `Delete` a book from the table.

# %%
cursor.execute("""
DELETE FROM books
WHERE book_id = 5;
""")
conn.commit()

# %% [markdown]
# ## **Activity 2**
#
# Practice using SQL queries with LIMIT, COUNT, and WHERE Clause along with comparison, logical, and special operators.
#
# ### **Perform the following tasks:**

# %% [markdown]
# 1. Create a table named `Students` and add these columns:
#   * **student_id** : This column stores the unique identifier for each student, serving as the primary key of the table.
#   * **name** : It holds the full name of the student, allowing for the storage of both the first name and last name within a maximum length of 50 characters.
#   * **age** : This column represents the age of the student in years, stored as an integer value.
#   * **gender** : It stores the gender of the student, allowing for the classification as either "Male" or "Female" within a maximum length of 10 characters.
#   * **grade** : This column holds the grade level of the student, typically represented by a single character such as 'A', 'B', 'C', 'D', indicating academic performance or class standing.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Students (
    student_id INTEGER PRIMARY KEY AUTOINCREMENT,
    name VARCHAR(50) NOT NULL,
    age INT NOT NULL,
    gender VARCHAR(10) NOT NULL,
    grade CHAR(1) NOT NULL
);
""")
conn.commit()

# %% [markdown]
# 2. Insert the provided data below into the students table.

# %% [markdown]
# | student_id | name             | age | gender | grade |
# | ---------- | ---------------- | --- | ------ | ----- |
# | 1          | John Di          | 18  | Male   | A     |
# | 2          | Emily Clark      | 17  | Female | B     |
# | 3          | Michael Santos   | 19  | Male   | C     |
# | 4          | Sarah Davis      | 16  | Female | A     |
# | 5          | David Poms       | 18  | Male   | B     |
# | 6          | Jessica Parker   | 17  | Female | A     |
# | 7          | Matthew Ross     | 19  | Male   | D     |
# | 8          | Ashey Lim        | 18  | Female | C     |
# | 9          | Christopher Chen | 17  | Male   | D     |
# | 10         | Amanda Hanes     | 16  | Female | B     |

# %%
cursor.execute("""
INSERT INTO Students (name, age, gender, grade)
VALUES
    ("John Di", 18, "Male", "A"),
    ("Emily Clark", 17, "Female", "B"),
    ("Michael Santos", 19, "Male", "C"),
    ("Sarah Davis", 16, "Female", "A"),
    ("David Poms", 18, "Male", "B"),
    ("Jessica Parker", 17, "Female", "A"),
    ("Matthew Ross", 19, "Male", "D"),
    ("Ashley Lim", 18, "Female", "C"),
    ("Christopher Chen", 17, "Male", "D"),
    ("Amanda Hanes", 16, "Female", "B");
""")
conn.commit()

# %% [markdown]
# 3. Retrieve only the name and grade columns for all students.

# %%
cursor.execute("SELECT name, grade FROM Students;")
cursor.fetchall()
# Out:
# [('John Di', 'A'),
#  ('Emily Clark', 'B'),
#  ('Michael Santos', 'C'),
#  ('Sarah Davis', 'A'),
#  ('David Poms', 'B'),
#  ('Jessica Parker', 'A'),
#  ('Matthew Ross', 'D'),
#  ('Ashley Lim', 'C'),
#  ('Christopher Chen', 'D'),
#  ('Amanda Hanes', 'B'),
#  ('John Di', 'A'),
#  ('Emily Clark', 'B'),
#  ('Michael Santos', 'C'),
#  ('Sarah Davis', 'A'),
#  ('David Poms', 'B'),
#  ('Jessica Parker', 'A'),
#  ('Matthew Ross', 'D'),
#  ('Ashley Lim', 'C'),
#  ('Christopher Chen', 'D'),
#  ('Amanda Hanes', 'B')]

# %% [markdown]
# 4. Retrieve male students older than 18 years old.

# %%
cursor.execute("""
SELECT * FROM Students 
WHERE gender = 'Male' AND age > 18;""")
cursor.fetchall()
# Out:
# [(3, 'Michael Santos', 19, 'Male', 'C'),
#  (7, 'Matthew Ross', 19, 'Male', 'D'),
#  (13, 'Michael Santos', 19, 'Male', 'C'),
#  (17, 'Matthew Ross', 19, 'Male', 'D')]

# %% [markdown]
# 5. Retrieve the name and age of students who are older than or equal to 18.

# %%
cursor.execute("""
SELECT name, age
FROM Students
WHERE age >= 18;
""")
cursor.fetchall()
# Out:
# [('John Di', 18),
#  ('Michael Santos', 19),
#  ('David Poms', 18),
#  ('Matthew Ross', 19),
#  ('Ashley Lim', 18),
#  ('John Di', 18),
#  ('Michael Santos', 19),
#  ('David Poms', 18),
#  ('Matthew Ross', 19),
#  ('Ashley Lim', 18)]

# %% [markdown]
# 6. Retrieve the name and gender of students who are either 16 years old or have a grade of 'A'.

# %%
cursor.execute("""
SELECT name, gender
FROM Students
WHERE age = 16 OR grade = 'A';
""")
cursor.fetchall()
# Out:
# [('John Di', 'Male'),
#  ('Sarah Davis', 'Female'),
#  ('Jessica Parker', 'Female'),
#  ('Amanda Hanes', 'Female'),
#  ('John Di', 'Male'),
#  ('Sarah Davis', 'Female'),
#  ('Jessica Parker', 'Female'),
#  ('Amanda Hanes', 'Female')]

# %% [markdown]
# 7. Retrieve the name, age, and grade of female students who are younger than 18.

# %%
cursor.execute("""
SELECT name, age, grade
FROM Students
WHERE gender = 'Female' AND age < 18;
""")
cursor.fetchall()
# Out:
# [('Emily Clark', 17, 'B'),
#  ('Sarah Davis', 16, 'A'),
#  ('Jessica Parker', 17, 'A'),
#  ('Amanda Hanes', 16, 'B'),
#  ('Emily Clark', 17, 'B'),
#  ('Sarah Davis', 16, 'A'),
#  ('Jessica Parker', 17, 'A'),
#  ('Amanda Hanes', 16, 'B')]

# %% [markdown]
# 8. Retrieve the count of male students.

# %%
cursor.execute("""
SELECT COUNT(*)
FROM Students
WHERE gender = 'Male';
""")
cursor.fetchall()
# Out:
# [(10,)]

# %% [markdown]
# 9. Retrieve the students who are between 16 or 19 years old.

# %%
cursor.execute("""
SELECT * FROM Students
WHERE age BETWEEN 16 AND 19;
""")
cursor.fetchall()
# Out:
# [(1, 'John Di', 18, 'Male', 'A'),
#  (2, 'Emily Clark', 17, 'Female', 'B'),
#  (3, 'Michael Santos', 19, 'Male', 'C'),
#  (4, 'Sarah Davis', 16, 'Female', 'A'),
#  (5, 'David Poms', 18, 'Male', 'B'),
#  (6, 'Jessica Parker', 17, 'Female', 'A'),
#  (7, 'Matthew Ross', 19, 'Male', 'D'),
#  (8, 'Ashley Lim', 18, 'Female', 'C'),
#  (9, 'Christopher Chen', 17, 'Male', 'D'),
#  (10, 'Amanda Hanes', 16, 'Female', 'B'),
#  (11, 'John Di', 18, 'Male', 'A'),
#  (12, 'Emily Clark', 17, 'Female', 'B'),
#  (13, 'Michael Santos', 19, 'Male', 'C'),
#  (14, 'Sarah Davis', 16, 'Female', 'A'),
#  (15, 'David Poms', 18, 'Male', 'B'),
#  (16, 'Jessica Parker', 17, 'Female', 'A'),
#  (17, 'Matthew Ross', 19, 'Male', 'D'),
#  (18, 'Ashley Lim', 18, 'Female', 'C'),
#  (19, 'Christopher Chen', 17, 'Male', 'D'),
#  (20, 'Amanda Hanes', 16, 'Female', 'B')]

# %% [markdown]
# 10. Retrieve the name and grade of students whose grades are 'B' or 'C' and are older than or equal to 18 years old.

# %%
cursor.execute("""
SELECT name, grade
FROM Students
WHERE (grade = 'B' OR grade = 'C') AND age >= 18;
""")
cursor.fetchall()
# Out:
# [('Michael Santos', 'C'),
#  ('David Poms', 'B'),
#  ('Ashley Lim', 'C'),
#  ('Michael Santos', 'C'),
#  ('David Poms', 'B'),
#  ('Ashley Lim', 'C')]

# %% [markdown]
# 11. Retrieve the name and age of students whose names start with 'A'.

# %%
cursor.execute("""
SELECT name, age
FROM Students
WHERE name LIKE 'A%';
""")
cursor.fetchall()
# Out:
# [('Ashley Lim', 18),
#  ('Amanda Hanes', 16),
#  ('Ashley Lim', 18),
#  ('Amanda Hanes', 16)]

# %% [markdown]
# 12. Retrieve the first 5 students whose names contain the letter 'i'.

# %%
cursor.execute("""
SELECT * 
FROM Students
WHERE name LIKE '%i%'
LIMIT 5;
""")
cursor.fetchall()
# Out:
# [(1, 'John Di', 18, 'Male', 'A'),
#  (2, 'Emily Clark', 17, 'Female', 'B'),
#  (3, 'Michael Santos', 19, 'Male', 'C'),
#  (4, 'Sarah Davis', 16, 'Female', 'A'),
#  (5, 'David Poms', 18, 'Male', 'B')]
